# %% [markdown]
# ### CSV files and pandas

# %% [markdown]
# Make sure you have pandas installed: `pip install pandas`. Your version (pd.\__version\__ should be > 2.0.0)

# %% [markdown]
# ### Read the csv file, `presidents_clean.csv`. Create a pie chart of president home states. Which state had the most presidents?

# %%
import pandas as pd

presidents = pd.read_csv("presidents_clean.csv")

# %%
presidents["home_state"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Now make a bar chart

# %%
presidents["home_state"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='home_state'>

# %% [markdown]
# > Answer: Ohio and New York

# %% [markdown]
# ### Convert both date columns into `datetime64`.

# %%
presidents["took_office"] = pd.to_datetime(presidents["took_office"])
presidents["left_office"] = pd.to_datetime(presidents["left_office"])

# %% [markdown]
# ### Which President had the longest terms in office? Who had the shortest?

# %%
# left office - took office = length of term
presidents["time_in_office"] = presidents["left_office"] - presidents["took_office"]

# %%
# use idxmin() to show the president who served the shortest term
presidents.loc[presidents["time_in_office"].idxmin()]
# Out:
# presidency                                                         9
# president                                     William Henry Harrison
# wikipedia_entry    http://en.wikipedia.org/wiki/William_Henry_Har...
# took_office                                      1841-03-04 00:00:00
# left_office                                      1841-04-04 00:00:00
# party                                                           Whig
# portrait                                    WilliamHenryHarrison.gif
# thumbnail                              thmb_WilliamHenryHarrison.gif
# home_state                                                      Ohio
# time_in_office                                      31 days 00:00:00
# Name: 8, dtype: object

# %% [markdown]
# ### Question 3: What is the average time of a president in office? What is mean and standard deviation of presidential terms?

# %%
print(f'mean: {presidents["time_in_office"].mean()}')
print(f'median: {presidents["time_in_office"].median()}')
print(f'standard deviation: {presidents["time_in_office"].std()}')
# Out:
# mean: 1867 days 01:40:27.906976736
# median: 1461 days 00:00:00
# standard deviation: 932 days 23:06:56.977889824

# %% [markdown]
# ### Question 4: List all presidents from Virginia in descending order of date of taking office

# %%
presidents[presidents["home_state"] == "Virginia"].sort_values(by="took_office")
# Out:
#    presidency          president  \
# 0           1  George Washington
# 2           3   Thomas Jefferson
# 3           4      James Madison
# 4           5       James Monroe
# 9          10         John Tyler
#
#                                   wikipedia_entry took_office left_office  \
# 0  http://en.wikipedia.org/wiki/George_Washington  1789-04-30  1797-04-03
# 2   http://en.wikipedia.org/wiki/Thomas_Jefferson  1801-04-03  1809-04-03
# 3      http://en.wikipedia.org/wiki/James_Madison  1809-04-03  1817-04-03
# 4       http://en.wikipedia.org/wiki/James_Monroe  1817-04-03  1825-04-03
# 9         http://en.wikipedia.org/wiki/John_Tyler  1841-04-04  1845-04-03
#
#                     party              portrait                  thumbnail  \
# 0            Independent   GeorgeWashington.jpg  thmb_GeorgeWashington.jpg
# 2  Democratic-Republican    Thomasjefferson.gif   thmb_Thomasjefferson.gif
# 3  Democratic-Republican       JamesMadison.gif      thmb_JamesMadison.gif
# 4  Democratic-Republican        JamesMonroe.gif       thmb_JamesMonroe.gif
# 9                    Whig         JohnTyler.jpg         thmb_JohnTyler.jpg
#
#   home_state time_in_office
# 0   Virginia      2895 days
# 2   Virginia      2922 days
# 3   Virginia      2922 days
# 4   Virginia      2922 days
# 9   Virginia      1460 days
